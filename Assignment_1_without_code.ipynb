# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1
# a) Load house sales data from file kc_house_data.csv, print first records.
# b) Print the variable list. Select categorical and numerical variables.
# c) Compute basic statistics of numerical variables. Are all of them meaningful?

# %%
#a)
#Your code:
df = pd.read_csv('./kc_house_data.csv')
df.head()


#Hint: read_csv(), head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# Note: with the help of function read_csv() we can load the data and the function head() prints first records. So, by using this functions, we can load house sales data from the file with extension csv and print first records. While doing this exercise I noticed that by giving a number n in head() function we can print n first records.

# %%
#b) 

print(df.columns)
house_categorical_df = df[["id", "grade", "view", "waterfront", "zipcode", "condition"]]
house_numerical_df = df[["date", "price", "bedrooms", "bathrooms", "sqft_living", "sqft_lot", "floors", "sqft_above", "sqft_basement", "yr_built", "yr_renovated", "lat", "long", "sqft_living15", "sqft_lot15"]]
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#c)
#Your code:

house_numerical_df.describe()


#Hint: Function describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       1.494309   1788.390691     291.509045   1971.005136     84.402258
# ...

# %% [markdown]
# Notes: In my opinion, not all of them are meaningful: I don't think that the count, which is all records number, is necessary. When we look at the column yr_renovated, we can see 0. It means that the house was not renovated and affects the result for this numerical variable(yr_renovated).

# %% [markdown]
# ## Exercise 2
# Using scatter plot:
# a) Show the relation of square footage and price.
# b) Check how price is influenced by apartment's grade. Find other variables correlated with price.
# c) Check how good apartments are distributed over the city. First, plot zipcode versus price. Then, use apartments coordinates (longitude and lattitude) in order to show where apartments of good grade are located.

# %%
#a)
#Your code:
plt.scatter(df['sqft_living'], df['price'])
plt.xlabel("living sqft")
plt.ylabel('price')
plt.ticklabel_format(style='plain', axis='y')
#Hint plt.scatter

# %%
#b)
#Your code:
plt.scatter(df['grade'], df['price'])
plt.xlabel('grade')
plt.ylabel('price')
plt.ticklabel_format(style='plain', axis='y')

# %%
#c)
#Your code:
plt.scatter(df['zipcode'], df['price'])
plt.xlabel("zipcode")
plt.ylabel('price')
plt.ticklabel_format(style='plain', axis='y')

# %%
#Your code:


plt.figure(figsize=(12, 8))
plt.xlabel("longitude")
plt.ylabel('lattitude')
plt.scatter(df['long'], df['lat'], c=df['grade'], cmap='winter')

# %% [markdown]
# ## Exercise 3
# a) Create boxplot of apartment's grade versus it's price. Compare with plot 2b).
# b) Create mosaic plot of any two categorical variables.

# %%
#a)
#Your code:
grades = sorted(df['grade'].unique())
data = [df[df['grade']==grade]['price'] for grade in grades]
flierprops = dict(marker='o', markerfacecolor='b', linestyle='none', markeredgecolor='b')
plt.boxplot(data, flierprops=flierprops)
#Hint: plt.boxplot
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fd83b9d5a10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fd83b9d6d10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fd83b9d51d0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7fd83b994bd0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd83b9e4590>,
# ...
#  'means': []}

# %%
#b)
from statsmodels.graphics.mosaicplot import mosaic

#Your code:

mosaic(df, ['bedrooms','bathrooms'])
# Out:
# (<Figure size 640x480 with 3 Axes>,
#  {('3', '1.0'): (0.0, 0.0, 0.4288124984177063, 0.16521786481589656),
#   ('3', '2.25'): (0.0,
#    0.1682573784937081,
#    0.4288124984177063,
#    0.1004301852420225),
#   ('3', '3.0'): (0.0,
#    0.27172707741354213,
#    0.4288124984177063,
#    0.018285347959961607),
#   ('3', '2.0'): (0.0,
#    0.2930519390513153,
#    0.4288124984177063,
#    0.09727433838598852),
#   ('3', '4.5'): (0.0,
#    0.3933657911151154,
#    0.4288124984177063,
#    0.00046409512588736274),
#   ('3', '1.5'): (0.0,
#    0.3968693999188143,
#    0.4288124984177063,
#    0.0769469718721226),
#   ('3', '2.5'): (0.0,
#    0.47685588546874846,
#    0.4288124984177063,
#    0.21877444234329674),
#   ('3', '1.75'): (0.0,
#    0.6986698414898568,
#    0.4288124984177063,
#    0.1735715770818688),
#   ('3', '2.75'): (0.0,
#    0.8752809322495371,
#    0.4288124984177063,
#    0.02552523192380424),
#   ('3', '3.25'): (0.0,
#    0.9038456778511529,
#    0.4288124984177063,
# ...

# %% [markdown]
# ## Exercise 4
# "I am interested in the house with 3 bedrooms, 2 bathrooms and 2 floors"
# a) Compute the basic statistics of apartments fulfilling above constraints.
# b) Distinct accepted apartments on any of previously created plots.
# c) Find such apartments with best price to footage ratio.

# %%
#a)
#Your code:
filtered = df.loc[(df['bedrooms'] == 3) & (df['bathrooms'] == 2) & (df['floors'] == 2)]
filtered.describe()

#Hint: pandas.DataFrame.loc
# Out:
#                  id         price  bedrooms  bathrooms  sqft_living  \
# count  1.540000e+02  1.540000e+02     154.0      154.0   154.000000
# mean   4.397177e+09  5.144986e+05       3.0        2.0  1850.279221
# std    2.849813e+09  2.497661e+05       0.0        0.0   547.585413
# min    7.600057e+06  2.090000e+05       3.0        2.0  1020.000000
# 25%    2.060901e+09  3.769750e+05       3.0        2.0  1452.500000
# 50%    3.630010e+09  4.640000e+05       3.0        2.0  1700.000000
# 75%    7.184074e+09  5.894625e+05       3.0        2.0  2127.500000
# max    9.829200e+09  1.755000e+06       3.0        2.0  3650.000000
#
#             sqft_lot  floors  waterfront        view   condition       grade  \
# count     154.000000   154.0  154.000000  154.000000  154.000000  154.000000
# mean    23678.948052     2.0    0.006494    0.357143    3.435065    7.551948
# std     83324.024708     0.0    0.080582    0.919495    0.713322    0.832684
# ...

# %%
#b)
#Your code:
fig, ax = plt.subplots()
ax.scatter(df['grade'], df['price'], c='black', s=3)
ax.scatter(filtered['grade'], filtered['price'], c='yellow', edgecolors='black')
plt.ticklabel_format(style='plain', axis='y')
plt.xlabel("grade")
plt.ylabel("price")
plt.show()

# %%
#c)
#Your code:
def calculate(row):
    row['price'] / row['sqft_living']
filtered['ratio'] = filtered.apply(calculate, axis=1)
filtered = filtered.sort_values(by='ratio')
filtered.head(5)
#Hint: .loc, .sort_values(), .index
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 9704   7452500565  20140829T000000  260000.0         3        2.0
# 11258  7937600262  20140710T000000  379900.0         3        2.0
# 19880  3832050860  20150319T000000  210000.0         3        2.0
# 16014  5104450440  20141113T000000  252500.0         3        2.0
# 20906  3355400242  20141028T000000  274900.0         3        2.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 9704          2710      5000     2.0           0     0  ...        2710
# 11258         3110     44967     2.0           0     0  ...        3020
# 19880         1580      4961     2.0           0     0  ...        1580
# 16014         1810     10684     2.0           0     0  ...        1810
# 20906         1936      6612     2.0           0     0  ...        1936
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...
